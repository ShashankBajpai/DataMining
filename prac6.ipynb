# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.cluster import hierarchical
from sklearn.cluster import DBSCAN
import pandas as pd
from sklearn.datasets import load_iris
    
iris = load_iris()
iris = iris.data
    
sep_l = iris[:,0]
pet_l = iris[:,1]
       
    
for i in range(150):
    if i<=49:
        plt.plot(iris[i:,1],iris[i:,2],'ro')
    if i>49 and i<=99:
        plt.plot(iris[i:,1],iris[i:,2],'bo')
    if i>99:
        plt.plot(iris[i:,1],iris[i:,2],'go')        
plt.show()        
        

plt.plot(iris[:,1],iris[:,2],'ro')
plt.show()
        
estimator1 = KMeans(n_clusters=3)
  
estimator1.fit(iris[:,1:3])
        
for i in range(150):
    if estimator1.labels_[i]==0:
        plt.plot(iris[i:,1],iris[i:,2],'go')
        plt.plot(estimator1.cluster_centers_[:,0],estimator1.cluster_centers_[:,1],'o',c='black')
    elif estimator1.labels_[i]==1:
        plt.plot(iris[i:,1],iris[i:,2],'ro')
        plt.plot(estimator1.cluster_centers_[:,0],estimator1.cluster_centers_[:,1],'o',c='black')
    elif estimator1.labels_[i]==2:
        plt.plot(iris[i:,1],iris[i:,2],'bo')
        plt.plot(estimator1.cluster_centers_[:,0],estimator1.cluster_centers_[:,1],'o',c='black')
plt.show()        

    
estimator2 = hierarchical.AgglomerativeClustering(n_clusters=3)
       
estimator2.fit(iris[:,1:3])
    
for i in range(150):
    if estimator2.labels_[i]==0:
        plt.plot(iris[i:,1],iris[i:,2],'go')
    elif estimator2.labels_[i]==1:
        plt.plot(iris[i:,1],iris[i:,2],'ro')
    elif estimator2.labels_[i]==2:
        plt.plot(iris[i:,1],iris[i:,2],'bo')
plt.show()        
        
estimator3 = DBSCAN()
    
estimator3.fit(iris[:,1:3])
    
for i in range(150):
    if estimator3.labels_[i]==0:
        plt.plot(iris[i:,1],iris[i:,2],'go')
    elif estimator3.labels_[i]==1:
        plt.plot(iris[i:,1],iris[i:,2],'ro')
    elif estimator3.labels_[i]==2:
        plt.plot(iris[i:,1],iris[i:,2],'bo')
plt.show()
